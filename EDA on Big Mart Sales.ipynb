# %% [markdown]
# 1. UNIVARIATE ANALYSIS:(SINGLE VARIABLE ANALYSIS)
#     NUMERICAL VARIABLES-
#     DISTPLOT,BOXPLOT,HISTOGRAMS
#
#     CATEGORICAL VARIABLES-
#     COUNTPLOT.
#
# 2.BIVARIATE ANALYSIS :IT IS DONE WITH RESPECT TO TARGET VARIABLE. WE CAN HAVE :
#     NUM VS NUM(SCATTERPLOT)
#     CAT VS NUM(BOXPLOT,VIOLINPLOT)
#     CAT VS CAT(PD.CROSSTAB() TO GENERATE THE FREQUENCY TABLE AND THEN COUNTPLOT)
# 3.FINDING MISSING VALUES:
# 4.OUTLIER ANALYSIS AND REMOVAL:
# 5.IMPORTANT-FEATURE ENGINEERING
# 6.SCALING AND TRANSFORMATION
# 7.CATEGORICAL ENCODING.
#
# **NOTE-ONCE THE ABOVE MENTIONED STEPS ARE DONE ,WE DEVIDE THE DATA INTO TRAIN AND TEST.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=[15,6]
import warnings
warnings.filterwarnings('ignore')

# %%
sales=pd.read_csv('~/downloads/train_data for eda.csv')
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # Statistical Summery

# %%
sales.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# # Data Information

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# # Univariate analysis on numerical Features.

# %%
sns.distplot(sales.Item_Weight)
plt.title('item_weight')
plt.show()

# %% [markdown]
# since the spreated of the data is high,we can assume that data is uniformly distributed.

# %%
# Target variable
sns.distplot(sales['Item_Outlet_Sales'])
plt.title('Target')
plt.show()

# %% [markdown]
# Item Outlet Sales seems to be perfectly posotive skewed .

# %%
#Statistical summary of the data
sales['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %%
sales['Item_Outlet_Sales'].skew()
# Out:
# 1.1775306028542796

# %%
sns.distplot(sales['Item_MRP'])
plt.title('mrp')
# Out:
# Text(0.5, 1.0, 'mrp')

# %% [markdown]
# It seems that there are 4 different mode in Item mrp feature.

# %%
sns.distplot(sales.Item_Visibility)
plt.title('item visibility')
# Out:
# Text(0.5, 1.0, 'item visibility')

# %%
sales.Item_Visibility.skew()
# Out:
# 1.1670905496918396

# %% [markdown]
# Item Visibility is perfectly positively skewed.

# %% [markdown]
# # univariate analysis on categorical features.

# %%
cat_cols=sales.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
cols=['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
rows=2
columns=3
iterator=1
for k in cols:
    plt.subplot(rows,columns,iterator)
    sns.countplot(sales.loc[:,k])
    plt.title(k)
    iterator+=1
plt.tight_layout()    
plt.show()

# %% [markdown]
# Infrence-This visualisation shows that people are buying Low fat more ,The most sales are comming from Supermarkets of tier 3
# of medium size.

# %% [markdown]
# # Bivariate analysis (Predictors vs Target)
#                           (Numric vs Numric)

# %%
num_cols=sales.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
cols=['Item_Weight', 'Item_Visibility', 'Item_MRP']

# %%
rows=1
columns=3
iterator=1
for k in cols:
    plt.subplot(rows,columns,iterator)
    sns.scatterplot(x=sales.loc[:,k],y=sales['Item_Outlet_Sales'],data=sales)
    plt.title(k)
    iterator+=1
plt.tight_layout()    
plt.show()

# %% [markdown]
# Infrence 1-There is not a much effect on the sales when the weight of the products are increasing.
# Infrence 2-As the product visibility increases the sales decreases, means small products are making high sales.
# Infrence 3-As the mpr increases the sales also increases.

# %% [markdown]
# # Bivariate analysis  - categorical vs numerical

# %%
cols=['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
rows=2
columns=3
iterator=1
for k in cols:
    plt.subplot(rows,columns,iterator)
    sns.boxplot(x=sales.loc[:,k],y=sales['Item_Outlet_Sales'])
    plt.title(k)
    iterator+=1
    plt.xticks(rotation=90)
plt.tight_layout()    
plt.show()

# %% [markdown]
# Infrence-1 Low fat products are making high sales
# Infrence-2 House Holds and Fruits -vegetables are the most
# Infrence-3 Outlet 27 is making highest sales
# Infrence-4 Medium size outlet seems to do the most sales
# Infrence-5 Tier 3 outlets make highest money
# Infrence-6 Mostly people are going to supermarkets

# %%
# Target variable analysis

# %%
sns.boxplot(sales.Item_Outlet_Sales)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %% [markdown]
# We can clearly see the outliers in our target feature.

# %% [markdown]
# Notes-1.Sales .quantile can calculate the quantile for all the numeric variables 2.Outliers can be defined as value >than q3+1.5IQR ,where IQR=Q3_Q1. 3.Inliers or the outliers on the Lower Level are defined as value< than q1-1.5IQR.

# %%
# Lets check the relation between all the numeric variables.

# %%
sns.heatmap(sales.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Range of correlation lies between(-1 to 1)

# %% [markdown]
# The more darker the rectangle the more relation exists.

# %%
sales.cov()
# Out:
#                            Item_Weight  Item_Visibility      Item_MRP  \
# Item_Weight                  21.561688        -0.003172      7.865693
# Item_Visibility              -0.003172         0.002662     -0.004225
# Item_MRP                      7.865693        -0.004225   3878.183909
# Outlet_Establishment_Year    -0.354551        -0.032325      2.617143
# Item_Outlet_Sales           100.560811       -11.325611  60317.485612
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.354551       1.005608e+02
# Item_Visibility                            -0.032325      -1.132561e+01
# Item_MRP                                    2.617143       6.031749e+04
# Outlet_Establishment_Year                  70.086372      -7.019621e+02
# Item_Outlet_Sales                        -701.962133       2.912141e+06

# %% [markdown]
# # Univariate -Categorical vs Categorical

# %%
cols=['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
#Lets compair the Outlet size with Outlet Location

pd.crosstab(sales['Outlet_Size'],sales['Outlet_Location_Type']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Outlet_Size'>

# %% [markdown]
#  Small size Outlets are mainly in tier 2.
# In Tier 3 there are a lot of medium size outlets.

# %% [markdown]
# # Dealing with null values

# %%
sales.isnull().sum()[sales.isnull().sum()!=0]
# Out:
# Item_Weight    1463
# Outlet_Size    2410
# dtype: int64

# %%
sales.groupby('Item_Identifier')['Item_Weight'].median()
# Out:
# Item_Identifier
# DRA12    11.600
# DRA24    19.350
# DRA59     8.270
# DRB01     7.390
# DRB13     6.115
#           ...
# NCZ30     6.590
# NCZ41    19.850
# NCZ42    10.500
# NCZ53     9.600
# NCZ54    14.650
# Name: Item_Weight, Length: 1559, dtype: float64

# %%
sales['Item_Weight']=sales.groupby('Item_Identifier')['Item_Weight'].transform(lambda x:x.fillna(x.median()))

# %%
sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
sales['Item_Weight']=sales.groupby('Item_Type')['Item_Weight'].transform(lambda x:x.fillna(x.median()))

# %% [markdown]
# There were around 2400 null values in Item weight we have sucessfully droped them.

# %%
filler=sales['Outlet_Size'].mode()[0]
filler
# Out:
# 'Medium'

# %%
sales['Outlet_Size'].fillna(filler,inplace=True)

# %%
sales.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# We have successsfully droped 2410 null values from Outlet Size

# %% [markdown]
# # FEATURE ENGINEERING

# %%
sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
sales['Item_Visibility']=sales.groupby('Item_Identifier')['Item_Visibility'].apply(lambda x:x.replace(0,x.median()))

# %%
sales['Item_Identifier']=sales['Item_Identifier'].apply(lambda x:x[:2])

# %%
sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FD         9.30          Low Fat         0.016047
# 1              DR         5.92          Regular         0.019278
# 2              FD        17.50          Low Fat         0.016760
# 3              FD        19.20          Regular         0.022861
# 4              NC         8.93          Low Fat         0.006590
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
sales['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
sales['Item_Fat_Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'},inplace=True)

# %%
sales.loc[sales.Item_Identifier=='NC','Item_Fat_Content']='Non Edible'

# %%
sales['Item_Identifier'].unique()
# Out:
# array(['FD', 'DR', 'NC'], dtype=object)

# %%
sales['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
perish=['Dairy','Meat','Fruits and Vegetables','Breakfast', 'Breads','Starchy Foods','Seafood']

# %%
def perish_ables(x):
    if x in perish:
        return 'perishable'
    else:
        return 'non perishable'

# %%
sales['Item_Type']=sales.Item_Type.apply(perish_ables)

# %%
sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FD         9.30          Low Fat         0.016047
# 1              DR         5.92          Regular         0.019278
# 2              FD        17.50          Low Fat         0.016760
# 3              FD        19.20          Regular         0.022861
# 4              NC         8.93       Non Edible         0.006590
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0      perishable  249.8092            OUT049                       1999
# 1  non perishable   48.2692            OUT018                       2009
# 2      perishable  141.6180            OUT049                       1999
# 3      perishable  182.0950            OUT010                       1998
# 4  non perishable   53.8614            OUT013                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
sales['Item_Type'].unique()
# Out:
# array(['perishable', 'non perishable'], dtype=object)

# %%
sales.drop(columns=['Item_Type','Outlet_Establishment_Year'])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0                 FD        9.300          Low Fat         0.016047  249.8092
# 1                 DR        5.920          Regular         0.019278   48.2692
# 2                 FD       17.500          Low Fat         0.016760  141.6180
# 3                 FD       19.200          Regular         0.022861  182.0950
# 4                 NC        8.930       Non Edible         0.006590   53.8614
# ...              ...          ...              ...              ...       ...
# 8518              FD        6.865          Low Fat         0.056783  214.5218
# 8519              FD        8.380          Regular         0.046982  108.1570
# 8520              NC       10.600       Non Edible         0.035186   85.1224
# 8521              FD        7.210          Regular         0.145221  103.1332
# 8522              DR       14.800          Low Fat         0.044878   75.4670
#
# ...

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()

# %%
cols=['Item_Weight','Item_Visibility','Item_MRP','Item_Outlet_Sales']

# %%
for k in cols:
    sales.loc[:,k]=sc.fit_transform(pd.DataFrame(sales.loc[:,k]))

# %%
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD    -0.769763          Low Fat        -1.083103
# 1                 DR    -1.497465          Regular        -1.018480
# 2                 FD     0.995668          Low Fat        -1.068846
# 3                 FD     1.361672          Regular        -0.946816
# 4                 NC    -0.849422       Non Edible        -1.272268
# ...              ...          ...              ...              ...
# 8518              FD    -1.294010          Low Fat        -0.268324
# 8519              FD    -0.967835          Regular        -0.464357
# 8520              NC    -0.489877       Non Edible        -0.700297
# 8521              FD    -1.219732          Regular         1.500544
# 8522              DR     0.414368          Low Fat        -0.506443
#
#            Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
sales=pd.get_dummies(sales,drop_first=True)

# %%
sales.drop('Outlet_Establishment_Year',axis=1,inplace=True)

# %%
sales
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  \
# 0       -0.769763        -1.083103  1.747454           0.910601
# 1       -1.497465        -1.018480 -1.489023          -1.018440
# 2        0.995668        -1.068846  0.010040          -0.049238
# 3        1.361672        -0.946816  0.660050          -0.849103
# 4       -0.849422        -1.272268 -1.399220          -0.695373
# ...           ...              ...       ...                ...
# 8518    -1.294010        -0.268324  1.180783           0.349915
# 8519    -0.967835        -0.464357 -0.527301          -0.956402
# 8520    -0.489877        -0.700297 -0.897208          -0.579100
# 8521    -1.219732         1.500544 -0.607977          -0.196725
# 8522     0.414368        -0.506443 -1.052261          -0.829594
#
#       Item_Identifier_FD  Item_Identifier_NC  Item_Fat_Content_Non Edible  \
# 0                      1                   0                            0
# ...
